# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris_data = pd.read_csv('iris.csv')
iris_data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data[iris_data.duplicated()]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 142           5.8          2.7           5.1          1.9  Virginica

# %%
iris_data['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
plt.title('‘Species Count’')
sns.set_palette("pastel")
sns.countplot(iris_data['variety'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'‘Species Count’'}, xlabel='variety', ylabel='count'>

# %%
plt.figure(figsize=(17,9))
sns.set_palette("pastel")
plt.title('Comparison between various species based on sepal length and width')
sns.scatterplot(iris_data['sepal.length'],iris_data['sepal.width'],hue =iris_data['variety'],s=50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between various species based on sepal length and width'}, xlabel='sepal.length', ylabel='sepal.width'>

# %%
plt.figure(figsize=(17,9))
plt.title('Comparison between various species based petal length and width')
sns.scatterplot(iris_data['petal.length'],iris_data['petal.width'],hue =iris_data['variety'],s=50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Comparison between various species based petal length and width'}, xlabel='petal.length', ylabel='petal.width'>

# %%
sns.set_style("dark")
sns.pairplot(iris_data,hue='variety', height=2)

# %%
plt.figure(figsize=(10,11))
sns.heatmap(iris_data.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
iris_data.groupby('variety').agg(['mean', 'median'])
# Out:
#            sepal.length        sepal.width        petal.length         \
#                    mean median        mean median         mean median
# variety
# Setosa            5.006    5.0       3.428    3.4        1.462   1.50
# Versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# Virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#            petal.width
#                   mean median
# variety
# Setosa           0.246    0.2
# Versicolor       1.326    1.3
# Virginica        2.026    2.0

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y='petal.width', x='variety', data=iris_data, orient='v' , ax=axes[0, 0])
sns.boxplot( y='petal.length', x='variety' , data=iris_data, orient='v' , ax=axes[0, 1])
sns.boxplot( y='sepal.length', x= 'variety', data=iris_data, orient='v' , ax=axes[1, 0])
sns.boxplot( y='sepal.width', x= 'variety', data=iris_data, orient='v' , ax=axes[1, 1])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.violinplot( y='petal.width', x='variety', data=iris_data, orient='v' , ax=axes[0, 0])
sns.violinplot( y='petal.length', x='variety' , data=iris_data, orient='v' , ax=axes[0, 1])
sns.violinplot( y='sepal.length', x= 'variety', data=iris_data, orient='v' , ax=axes[1, 0])
sns.violinplot( y='sepal.width', x= 'variety', data=iris_data, orient='v' , ax=axes[1, 1])
plt.show()

# %%
sns.set_palette("tab10")

sns.FacetGrid(iris_data, hue='variety', height=5) \
.map(sns.distplot, "sepal.length") \
.add_legend()
sns.FacetGrid(iris_data, hue='variety', height=5) \
.map(sns.distplot, "sepal.width") \
.add_legend()
sns.FacetGrid(iris_data, hue='variety', height=5) \
.map(sns.distplot, "petal.length") \
.add_legend()
sns.FacetGrid(iris_data, hue='variety', height=5) \
.map(sns.distplot, "petal.width") \
.add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from scipy.stats import shapiro

stat, p = shapiro(iris_data['petal.length'])
print('Shapiro-Wilk Test for Petal Length:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = shapiro(iris_data['petal.width'])
print('Shapiro-Wilk Test for Petal Width:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = shapiro(iris_data['sepal.length'])   
print('Shapiro-Wilk Test for Sepal Length:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = shapiro(iris_data['sepal.width'])
print('Shapiro-Wilk Test for Sepal Width:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')
# Out:
# Shapiro-Wilk Test for Petal Length:
# Statistics=0.876, p=0.000
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for Petal Width:
# Statistics=0.902, p=0.000
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for Sepal Length:
# Statistics=0.976, p=0.010
# Sample does not look Gaussian (reject H0)
#
# Shapiro-Wilk Test for Sepal Width:
# Statistics=0.985, p=0.101
# Sample looks Gaussian (fail to reject H0)

# %%
from scipy.stats import kstest

stat, p = kstest(iris_data['petal.length'], 'norm')
print('Kolmogorov-Smirnof Test for Petal Length:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = kstest(iris_data['petal.width'], 'norm')
print('Kolmogorov-Smirnof Test for Petal Width:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = kstest(iris_data['sepal.length'], 'norm')   
print('Kolmogorov-Smirnof Test for Sepal Length:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')

stat, p = kstest(iris_data['sepal.width'], 'norm')
print('Kolmogorov-Smirnof Test for Sepal Width:')
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)\n')
else:
    print('Sample does not look Gaussian (reject H0)\n')
# Out:
# Kolmogorov-Smirnof Test for Petal Length:
# Statistics=0.877, p=0.000
# Sample does not look Gaussian (reject H0)
#
# Kolmogorov-Smirnof Test for Petal Width:
# Statistics=0.546, p=0.000
# Sample does not look Gaussian (reject H0)
#
# Kolmogorov-Smirnof Test for Sepal Length:
# Statistics=1.000, p=0.000
# Sample does not look Gaussian (reject H0)
#
# Kolmogorov-Smirnof Test for Sepal Width:
# Statistics=0.979, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
def linear_assumption(model, features, label):
    """
    Linearity: Assumes that there is a linear relationship between the predictors and
               the response variable. If not, either a quadratic term or another
               algorithm should be used.
    """
    print('Assumption 1: Linear Relationship between the Target and the Feature', '\n')
        
    print('Checking with a scatter plot of actual vs. predicted.',
           'Predictions should follow the diagonal line.')
    
    # Calculating residuals for the plot
    df_results = calculate_residuals(model, features, label)
    
    # Plotting the actual vs predicted values
    sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False, size=7)
        
    # Plotting the diagonal line
    line_coords = np.arange(df_results.min().min(), df_results.max().max())
    plt.plot(line_coords, line_coords,  # X and y points
             color='darkorange', linestyle='--')
    plt.title('Actual vs. Predicted')
    plt.show()
